# %% [markdown]
# # Data Analysis

# %%
import os
import pandas as pd

'''
# List of file names
file_list = [
    'grid_search_results_4_patches_1DD_perlin.csv',
    'grid_search_results_4_patches_5DD_perlin.csv',
    'grid_search_results_patches_1DD_blur_0.csv',
    'grid_search_results_patches_1DD_blur_3.csv',
    'grid_search_results_patches_1DD_perlin.csv',
    'grid_search_results_patches_4_1DD_blur_0.csv',
    'grid_search_results_patches_4_1DD_blur_3.csv',
    'grid_search_results_patches_4_5DD_blur_0.csv',
    'grid_search_results_patches_4_5DD_blur_3.csv',
    'grid_search_results_patches_5DD_blur_0.csv',
    'grid_search_results_patches_5DD_blur_3.csv',
    'grid_search_results_patches_5DD_perlin.csv',
    'grid_search_results_patches_9_1DD_blur_0.csv',
    'grid_search_results_patches_9_1DD_blur_3.csv',
    'grid_search_results_patches_9_1DD_perlin.csv',
    'grid_search_results_patches_9_5DD_blur_0.csv',
    'grid_search_results_patches_9_5DD_blur_3.csv',
    'grid_search_results_patches_9_5DD_perlin.csv',
    'grid_search_results_patches2_1DD_blur_0.csv',
    'grid_search_results_patches2_1DD_blur_3.csv',
    'grid_search_results_patches2_5DD_blur_0.csv',
    'grid_search_results_slice_1DD_blur_0.csv',
    'grid_search_results_slice_1DD_blur_3.csv',
    'grid_search_results_slice_1DD_perlin.csv',
    'grid_search_results_slice_5DD_blur_0.csv',
    'grid_search_results_slice_5DD_blur_3.csv',
    'grid_search_results_slice_5DD_perlin.csv',
    'grid_search_results_slice2_1DD_blur_0.csv',
    'grid_search_results_slice2_1DD_blur_3.csv',
    'grid_search_results_slice2_5DD_blur_0.csv',
    'grid_search_results_slice2_5DD_blur_3.csv'
]

'''

# Manually create separate variables for each dataframe
df_4_patches_1DD_perlin = pd.read_csv('grid_search_results_4_patches_1DD_perlin.csv')
df_4_patches_5DD_perlin = pd.read_csv('grid_search_results_4_patches_5DD_perlin.csv')
df_patches_1DD_blur_0 = pd.read_csv('grid_search_results_patches_1DD_blur_0.csv')
df_patches_1DD_blur_3 = pd.read_csv('grid_search_results_patches_1DD_blur_3.csv')
df_patches_1DD_perlin = pd.read_csv('grid_search_results_patches_1DD_perlin.csv')
df_patches_4_1DD_blur_0 = pd.read_csv('grid_search_results_patches_4_1DD_blur_0.csv')
df_patches_4_1DD_blur_3 = pd.read_csv('grid_search_results_patches_4_1DD_blur_3.csv')
df_patches_4_5DD_blur_0 = pd.read_csv('grid_search_results_patches_4_5DD_blur_0.csv')
df_patches_4_5DD_blur_3 = pd.read_csv('grid_search_results_patches_4_5DD_blur_3.csv')
df_patches_5DD_blur_0 = pd.read_csv('grid_search_results_patches_5DD_blur_0.csv')
df_patches_5DD_blur_3 = pd.read_csv('grid_search_results_patches_5DD_blur_3.csv')
df_patches_5DD_perlin = pd.read_csv('grid_search_results_patches_5DD_perlin.csv')
df_patches_9_1DD_blur_0 = pd.read_csv('grid_search_results_patches_9_1DD_blur_0.csv')
df_patches_9_1DD_blur_3 = pd.read_csv('grid_search_results_patches_9_1DD_blur_3.csv')
df_patches_9_1DD_perlin = pd.read_csv('grid_search_results_patches_9_1DD_perlin.csv')
df_patches_9_5DD_blur_0 = pd.read_csv('grid_search_results_patches_9_5DD_blur_0.csv')
df_patches_9_5DD_blur_3 = pd.read_csv('grid_search_results_patches_9_5DD_blur_3.csv')
df_patches_9_5DD_perlin = pd.read_csv('grid_search_results_patches_9_5DD_perlin.csv')
df_patches2_1DD_blur_0 = pd.read_csv('grid_search_results_patches2_1DD_blur_0.csv')
df_patches2_1DD_blur_3 = pd.read_csv('grid_search_results_patches2_1DD_blur_3.csv')
df_patches2_5DD_blur_0 = pd.read_csv('grid_search_results_patches2_5DD_blur_0.csv')
df_slice_1DD_blur_0 = pd.read_csv('grid_search_results_slice_1DD_blur_0.csv')
df_slice_1DD_blur_3 = pd.read_csv('grid_search_results_slice_1DD_blur_3.csv')
df_slice_1DD_perlin = pd.read_csv('grid_search_results_slice_1DD_perlin.csv')
df_slice_5DD_blur_0 = pd.read_csv('grid_search_results_slice_5DD_blur_0.csv')
df_slice_5DD_blur_3 = pd.read_csv('grid_search_results_slice_5DD_blur_3.csv')
df_slice_5DD_perlin = pd.read_csv('grid_search_results_slice_5DD_perlin.csv')
df_slice2_1DD_blur_0 = pd.read_csv('grid_search_results_slice2_1DD_blur_0.csv')
df_slice2_1DD_blur_3 = pd.read_csv('grid_search_results_slice2_1DD_blur_3.csv')
df_slice2_5DD_blur_0 = pd.read_csv('grid_search_results_slice2_5DD_blur_0.csv')
df_slice2_5DD_blur_3 = pd.read_csv('grid_search_results_slice2_5DD_blur_3.csv')

# %%
# List of dataframe variable names
df_names_5DD = [
    'df_4_patches_5DD_perlin',
    'df_patches_4_5DD_blur_0',
    'df_patches_4_5DD_blur_3',
    'df_patches_5DD_blur_0',
    'df_patches_5DD_blur_3',
    'df_patches_5DD_perlin',
    'df_patches_9_5DD_blur_0',
    'df_patches_9_5DD_blur_3',
    'df_patches_9_5DD_perlin',
    'df_slice_5DD_blur_0',
    'df_slice_5DD_blur_3',
    'df_slice_5DD_perlin',
    'df_slice2_5DD_blur_0',
    'df_slice2_5DD_blur_3'
]

# Check if 'PSNR Variance' column is present in each dataframe
for df_name in df_names_5DD:
    df = globals()[df_name]  # Get the dataframe from the variable name
    if 'PSNR Variance' not in df.columns:
        print(f"{df_name}.")
# Out:
# df_4_patches_5DD_perlin.
# df_patches_5DD_perlin.
# df_patches_9_5DD_perlin.
# df_slice_5DD_perlin.

# %%
df_4_patches_5DD_perlin = pd.read_csv('grid_search_results_4_patches_5DD_perlin.csv')
df_patches_5DD_perlin = pd.read_csv('grid_search_results_patches_5DD_perlin.csv')
df_patches_9_5DD_perlin = pd.read_csv('grid_search_results_patches_9_5DD_perlin.csv')
df_slice_5DD_perlin = pd.read_csv('grid_search_results_slice_5DD_perlin.csv')

# %%
df_4_patches_5DD_perlin
# Out:
#      Run Number_of_hidden_channels  Input_shape  Number_of_layers  \
# 0      8                    [4, 5]            4              2000
# 1      8                    [4, 5]            4              5000
# 2      8                    [4, 5]            4              7000
# 3      8                    [4, 5]            5              2000
# 4      8                    [4, 5]            5              5000
# ..   ...                       ...          ...               ...
# 184  192                  [16, 20]            5              5000
# 185  192                  [16, 20]            5              7000
# 186  192                  [16, 20]            6              2000
# 187  192                  [16, 20]            6              5000
# 188  192                  [16, 20]            6              7000
#
#      Number_of_iterations          PSNR      SSIM       VIF  \
# 0               22.244701  5.773762e-01  0.544601  0.124359
# ...

# %%
df_4_patches_5DD_perlin.reset_index(inplace=True)
df_patches_5DD_perlin.reset_index(inplace=True)
df_patches_9_5DD_perlin.reset_index(inplace=True)
df_slice_5DD_perlin.reset_index(inplace=True)

# %%
df_4_patches_5DD_perlin
# Out:
#      index  Run Number_of_hidden_channels  Input_shape  Number_of_layers  \
# 0        0    8                    [4, 5]            4              2000
# 1        1    8                    [4, 5]            4              5000
# 2        2    8                    [4, 5]            4              7000
# 3        3    8                    [4, 5]            5              2000
# 4        4    8                    [4, 5]            5              5000
# ..     ...  ...                       ...          ...               ...
# 184    184  192                  [16, 20]            5              5000
# 185    185  192                  [16, 20]            5              7000
# 186    186  192                  [16, 20]            6              2000
# 187    187  192                  [16, 20]            6              5000
# 188    188  192                  [16, 20]            6              7000
#
#      Number_of_iterations          PSNR      SSIM       VIF  \
# ...

# %%
df_4_patches_5DD_perlin.columns = ['Run', 'Number_of_hidden_channels', 'Input_shape', 'Number_of_layers', 'Number_of_iterations',
                'PSNR', 'PSNR Variance', 'SSIM', 'VIF', 'Number_of_parameters', 'Execution_time']
df_patches_5DD_perlin.columns = ['Run', 'Number_of_hidden_channels', 'Input_shape', 'Number_of_layers', 'Number_of_iterations',
                'PSNR', 'PSNR Variance', 'SSIM', 'VIF', 'Number_of_parameters', 'Execution_time']
df_patches_9_5DD_perlin.columns = ['Run', 'Number_of_hidden_channels', 'Input_shape', 'Number_of_layers', 'Number_of_iterations',
                'PSNR', 'PSNR Variance', 'SSIM', 'VIF', 'Number_of_parameters', 'Execution_time']
df_slice_5DD_perlin.columns = ['Run', 'Number_of_hidden_channels', 'Input_shape', 'Number_of_layers', 'Number_of_iterations',
                'PSNR', 'PSNR Variance', 'SSIM','MS-SSIM', 'VIF', 'Number_of_parameters', 'Execution_time']

# %%
df_4_patches_5DD_perlin
# Out:
#      Run  Number_of_hidden_channels Input_shape  Number_of_layers  \
# 0      0                          8      [4, 5]                 4
# 1      1                          8      [4, 5]                 4
# 2      2                          8      [4, 5]                 4
# 3      3                          8      [4, 5]                 5
# 4      4                          8      [4, 5]                 5
# ..   ...                        ...         ...               ...
# 184  184                        192    [16, 20]                 5
# 185  185                        192    [16, 20]                 5
# 186  186                        192    [16, 20]                 6
# 187  187                        192    [16, 20]                 6
# 188  188                        192    [16, 20]                 6
#
#      Number_of_iterations       PSNR  PSNR Variance      SSIM       VIF  \
# 0                    2000  22.244701   5.773762e-01  0.544601  0.124359
# ...

# %%
df_4_patches_5DD_perlin.to_csv('grid_search_results_4_patches_5DD_perlin.csv', index=False)
df_patches_5DD_perlin.to_csv('grid_search_results_patches_5DD_perlin.csv', index=False)
df_patches_9_5DD_perlin.to_csv('grid_search_results_patches_9_5DD_perlin.csv', index=False)
df_slice_5DD_perlin.to_csv('grid_search_results_slice_5DD_perlin.csv', index=False)

# %%
df = pd.read_csv('A2Agrid_search_results_4_patches_5DD_perlin.csv')

# %%
df
# Out:
#      Run  Number_of_hidden_channels Input_shape  Number_of_layers  \
# 0      0                          8     [8, 10]                 4
# 1      1                          8     [8, 10]                 4
# 2      2                          8     [8, 10]                 4
# 3      3                          8     [8, 10]                 5
# 4      4                          8     [8, 10]                 5
# ..   ...                        ...         ...               ...
# 184  184                        192    [32, 40]                 5
# 185  185                        192    [32, 40]                 5
# 186  186                        192    [32, 40]                 6
# 187  187                        192    [32, 40]                 6
# 188  188                        192    [32, 40]                 6
#
#      Number_of_iterations       PSNR  PSNR Variance      SSIM   MS-SSIM  \
# 0                    2000  20.835045       0.452903  0.468171  0.638138
# ...

# %%
df = pd.read_csv('output.csv')

# %%
column_names = ['Run', 'Number_of_hidden_channels', 'Input_shape', 'Number_of_layers', 'Number_of_iterations',
                'PSNR', 'PSNR Variance', 'SSIM', 'VIF', 'Number_of_parameters', 'Execution_time']
df_4_patches_5DD_perlin.rename(columns=new_column_names, inplace=True)

# %%
df
